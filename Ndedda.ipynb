# %% [markdown]
# OBJECTIVES
#
# 1. Find the most popupous movies
# 2. Checking the rating distribution among the movies
# 3. Finding most populous movies by their original language

# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Loading the data
movies = pd.read_csv("tmdb.movies.csv")
movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
# Checking for the basic info of the dataset
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
# Checking for column names
movies.columns
# Out:
# Index(['Unnamed: 0', 'genre_ids', 'id', 'original_language', 'original_title',
#        'popularity', 'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
# Checking for the number of rows nd columns of the datset
movies.shape
# Out:
# (26517, 10)

# %%
# Checking for the statistical summary of the dataset
movies.describe()
# Out:
#         Unnamed: 0             id    popularity  vote_average    vote_count
# count  26517.00000   26517.000000  26517.000000  26517.000000  26517.000000
# mean   13258.00000  295050.153260      3.130912      5.991281    194.224837
# std     7654.94288  153661.615648      4.355229      1.852946    960.961095
# min        0.00000      27.000000      0.600000      0.000000      1.000000
# 25%     6629.00000  157851.000000      0.600000      5.000000      2.000000
# 50%    13258.00000  309581.000000      1.374000      6.000000      5.000000
# 75%    19887.00000  419542.000000      3.694000      7.000000     28.000000
# max    26516.00000  608444.000000     80.773000     10.000000  22186.000000

# %%
# Checking for the summary of the datset other than numerical analysis
movies.describe(include=['object', 'bool'])
# Out:
#        genre_ids original_language original_title release_date  title
# count      26517             26517          26517        26517  26517
# unique      2477                76          24835         3433  24688
# top         [99]                en           Eden   2010-01-01   Home
# freq        3700             23291              7          269      7

# %%
# Checking if there are any duplicated values in the datset
movies.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 26512    False
# 26513    False
# 26514    False
# 26515    False
# 26516    False
# Length: 26517, dtype: bool

# %%
# Checking for the total number of duplicated data
movies.duplicated().sum()
# Out:
# 0

# %%
# Checking for missing values in the dataset
movies.isna()
# Out:
#        Unnamed: 0  genre_ids     id  original_language  original_title  \
# 0           False      False  False              False           False
# 1           False      False  False              False           False
# 2           False      False  False              False           False
# 3           False      False  False              False           False
# 4           False      False  False              False           False
# ...           ...        ...    ...                ...             ...
# 26512       False      False  False              False           False
# 26513       False      False  False              False           False
# 26514       False      False  False              False           False
# 26515       False      False  False              False           False
# 26516       False      False  False              False           False
#
#        popularity  release_date  title  vote_average  vote_count
# ...

# %%
# Checking for number of missing values in each column
movies.isna().sum()
# Out:
# Unnamed: 0           0
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
# Top 10 most popular movies
top_popular = movies.sort_values('popularity', ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x='popularity', y='title', data=top_popular, palette='viridis')
plt.title('Top 10 Most Popular Movies')
plt.xlabel('Popularity Score')
plt.ylabel('Movie Title')
plt.tight_layout()
plt.show()

# %%
# Top 10 most voted movies
top_votes = movies.sort_values('vote_count', ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x='vote_count', y='title', data=top_votes, palette='magma')
plt.title('Top 10 Movies by Number of Votes')
plt.xlabel('Number of Votes')
plt.ylabel('Movie Title')
plt.tight_layout()
plt.show()

# %%
# Vote average
plt.figure(figsize=(8,5))
sns.histplot(movies['vote_average'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Movie Ratings')
plt.xlabel('Average Rating')
plt.ylabel('Number of Movies')
plt.tight_layout()
plt.show()

# %%
# Movies released per year
# Assuming you have a 'release_date' column
movies['release_date'] = pd.to_datetime(movies['release_date'], errors='coerce')
movies['release_year'] = movies['release_date'].dt.year

movies_per_year = movies['release_year'].value_counts().sort_index()

plt.figure(figsize=(12,6))
movies_per_year.plot(kind='line')
plt.title('Number of Movies Released Per Year')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Checking for the most popular language for movies
movies['original_language'].value_counts()
# Out:
# en    23291
# fr      507
# es      455
# ru      298
# ja      265
#       ...
# cr        1
# xh        1
# af        1
# sw        1
# mi        1
# Name: original_language, Length: 76, dtype: int64

# %%
# Checking for the best rated language movies
top_genres = movies.groupby('original_language')['popularity'].mean().sort_values(ascending=False)
top_genres.head(10)
# Out:
# original_language
# nb    8.221000
# sw    7.440000
# ja    5.711072
# hz    5.495000
# uk    5.331000
# id    5.187000
# af    4.814000
# sv    4.799897
# mi    4.746000
# ko    4.697441
# Name: popularity, dtype: float64
